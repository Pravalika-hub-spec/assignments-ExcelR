# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\DELL\\Downloads\\DATASCIENCE ASSIGNMENTS\\Online retail.csv")

# %%
print(data.columns)
# Out:
# Index(['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil'], dtype='object')

# %%
from mlxtend.preprocessing import TransactionEncoder
# Convert the column with item lists into a list of lists
transactions = data['shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil'].apply(lambda x: x.split(','))
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False    False              False      False    False        False
# 1       False    False              False      False    False        False
# 2       False    False              False      False     True        False
# 3       False    False              False      False    False        False
# 4       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False           False
# 1  False           False      False        False  ...   False           False
# 2  False           False      False        False  ...    True           False
# 3  False           False      False        False  ...   False           False
# 4  False           False      False        False  ...   False           False
#
# ...

# %% [markdown]
# # Data Preprocessing:

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (5153, 120)

# %% [markdown]
# # Association Rule Mining:

# %%
from mlxtend.frequent_patterns import apriori,association_rules

# %%
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#       support                               itemsets
# 0    0.029303                              (almonds)
# 1    0.011062                    (antioxydant juice)
# 2    0.045993                              (avocado)
# 3    0.012614                                (bacon)
# 4    0.015525                       (barbecue sauce)
# ..        ...                                    ...
# 431  0.014749  (spaghetti, olive oil, mineral water)
# 432  0.016689   (spaghetti, pancakes, mineral water)
# 433  0.012420     (shrimp, spaghetti, mineral water)
# 434  0.010867       (spaghetti, soup, mineral water)
# 435  0.013584   (spaghetti, mineral water, tomatoes)
#
# [436 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
rules
# Out:
#                    antecedents                 consequents  \
# 0              (mineral water)                   (almonds)
# 1                    (almonds)             (mineral water)
# 2                  (chocolate)                   (avocado)
# 3                    (avocado)                 (chocolate)
# 4                    (avocado)              (french fries)
# ..                         ...                         ...
# 947      (spaghetti, tomatoes)             (mineral water)
# 948  (mineral water, tomatoes)                 (spaghetti)
# 949                (spaghetti)   (mineral water, tomatoes)
# 950            (mineral water)       (spaghetti, tomatoes)
# 951                 (tomatoes)  (spaghetti, mineral water)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.299825            0.029303  0.010867    0.036246  1.236923
# 1              0.029303            0.299825  0.010867    0.370861  1.236923
# ...

# %%
rules_sorted = rules.sort_values(by='lift', ascending=False)
rules_sorted
# Out:
#                antecedents            consequents  antecedent support  \
# 519            (olive oil)    (whole wheat pasta)            0.087910
# 518    (whole wheat pasta)            (olive oil)            0.040753
# 906  (mineral water, milk)                 (soup)            0.067922
# 907                 (soup)  (mineral water, milk)            0.071221
# 391        (herb & pepper)          (ground beef)            0.066757
# ..                     ...                    ...                 ...
# 282               (shrimp)         (french fries)            0.099166
# 748  (mineral water, eggs)         (french fries)            0.070056
# 753         (french fries)  (mineral water, eggs)            0.192897
# 751        (mineral water)   (eggs, french fries)            0.299825
# 750   (eggs, french fries)        (mineral water)            0.046575
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# ...

# %% [markdown]
# # Interview Questions:

# %% [markdown]
# # 1.	What is lift and why is it important in Association rules?
#
# The lift value is an important measure in association rule mining because it provides a way to distinguish between significant and insignificant association rules.
# A high lift value indicates that the association rule is more significant, as it suggests that the two items are highly dependent on each other.

# %% [markdown]
# # 2.	What is support and Confidence. How do you calculate them?
# SUPPORT:
# Support is a number of transactions in which antecedent and consequent appear in the data
#
# calculation:
#
# Transaction with antecedent and consequent / Total Transactions
#
#
# CONFIDENCE:
# Confidence is a number of antecedent transactions that also have the consequent item set
#
# Calculation:
#
# Transactions with antecedent and consequent /Transaction with anteceden

# %% [markdown]
# # 3.	What are some limitations or challenges of Association rules mining?
# In data mining, association rules are useful for analyzing and predicting customer behavior. The primary disadvantages of association rule algorithms are obtaining boring rules, having a large number of discovered rules, and low algorithm performance.
